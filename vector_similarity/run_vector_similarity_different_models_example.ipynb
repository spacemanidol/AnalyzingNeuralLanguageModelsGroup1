# %%
import run_vector_similarity

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
class objectview(object):
    def __init__(self, d):
        self.__dict__ = d

# %% [markdown]
# #  BERT - LARGE

# %%
# BERT - LARGE

word_args = {
   'comparison_type': 'words',
    'input': 'word_vec_sim_test.txt',
    'embedding_model': 'bert-large-uncased',
    'run_name': 'bert_large_1',
    'embedding_batch_size': 32,
#     'embedding_cache': 'cache/bert_large_1',
    'embedding_cache': None,
    'show_pca': True
}

run_vector_similarity.main(objectview(word_args))
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', description='Feature extraction', max=1, style=ProgressS…
# Example 0
# Figurative phrases:
# soon we ' re going to hit the sack .
# so if you ' re exercising close to bed ##time , calm down by med ##itating or doing a few gentle yoga poses before you hit the sack .
# would it be okay with you if we had a bite to eat now and hit the sack early ?
# i think i ' m gonna hit the sack before i get even more uncomfortable .
# but before you hit the sack , follow this expert advice for solving morning beauty emergencies .
#
# Idiom usage word:  sack
# Paraphrase word:  bed
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.5078671508365207
# literal_to_literal : 0.7760081407096651
# fig_to_fig : 0.7589948058128357
# fig_to_paraphrase : 0.455306636095047
# literal_to_paraphrase : 0.4630802750587463
# fig_to_random : 0.45725299499251626
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 12.871600045098198
# literal_to_literal : 8.766190078523424
# fig_to_fig : 8.801383209228515
# fig_to_paraphrase : 13.97687313079834
# literal_to_paraphrase : 14.01913865407308
# fig_to_random : 13.06278093511408
#
#
#
#
#
# Example 1
# Figurative phrases:
# it ' s not always easy making decisions on the fly as a d ##m but here ' s what he probably should have done so that it wasn ' t obvious .
# that ' s a fairly advanced feature for any presentation device and requires a lot of computing power to do on the fly .
# but i certainly won ' t let them know i ' m t ##we ##aking things on the fly .
# operating on the fly , obama made a tough call and it seems like it was a good one .
# often these changes happened on the fly , daily , in response to sudden customer demand or customer loss .
#
# Idiom usage word:  fly
# Paraphrase word:  spontaneously
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.5233455277979374
# literal_to_literal : 0.6911123735564095
# fig_to_fig : 0.7300763607025147
# fig_to_paraphrase : 0.4885933816432953
# literal_to_paraphrase : 0.405544331127947
# fig_to_random : 0.44741252931681547
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 13.374812078475951
# literal_to_literal : 10.407371946743556
# fig_to_fig : 10.185891437530518
# fig_to_paraphrase : 13.609188964150169
# literal_to_paraphrase : 14.24409579146992
# fig_to_random : 13.914270262284713
#
#
#
#
#
# Example 2
# Figurative phrases:
# razor is aiming for that same market corner and they have set the bar rather high for it based on speculation .
# but apple has set the bar for magical technology and the iphone 5 failed to impress .
# take care not to set the bar too low - - - - low goals will not mo ##tiv ##ate you .
# it ' s worth noting for rams fans , though , that they set the bar insane ##ly high by hitting on so many rookie ##s .
# after it was released in 1998 , grim fan ##dan ##go blew everyone away and set the bar ridiculous ##ly high for adventure games .
#
# Idiom usage word:  bar
# Paraphrase word:  standard
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.5169897384113735
# literal_to_literal : 0.8094712528917525
# fig_to_fig : 0.8359665513038635
# fig_to_paraphrase : 0.48567103981971743
# literal_to_paraphrase : 0.4168248636855019
# fig_to_random : 0.4187466350468722
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 13.89927135043674
# literal_to_literal : 7.952579180399577
# fig_to_fig : 8.70262770652771
# fig_to_paraphrase : 14.385706424713135
# literal_to_paraphrase : 13.889313263363308
# fig_to_random : 14.990894040194425
#
#
#
#
#
# Example 3
# Figurative phrases:
# i dunn ##o , what ' s the opportunity cost in the long run ?
# that marriage must be good for children is an argument that , by itself , can not pre ##va ##il in the attempt to preserve marriage in the long run .
# i would suggest buying your milk at grocery stores , in the long run you ' ll save money versus making multiple trips .
# in the long run , people buy from artists they trust .
# some organizations thrive for only a few quarters , but in the long run , they may be extremely unstable .
#
# Idiom usage word:  run
# Paraphrase word:  future
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.4953496098518372
# literal_to_literal : 0.7137141070432134
# fig_to_fig : 0.7929155468940735
# fig_to_paraphrase : 0.5862216567993164
# literal_to_paraphrase : 0.4257318605979284
# fig_to_random : 0.4073615074157715
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 14.23606334262424
# literal_to_literal : 10.233065101835463
# fig_to_fig : 9.518894863128661
# fig_to_paraphrase : 12.695237731933593
# literal_to_paraphrase : 14.327840412987603
# fig_to_random : 14.981421258714464
#
#
#
#
#
# Example 4
# Figurative phrases:
# you ' re just going to have to bite the bullet and get through it .
# one possible response to this second example is to bite the bullet and to argue that from the point of view of fundamental physics , there really is no difference .
# like everything else in life , you ' re kind of just forced to bite the bullet and see the bigger picture .
# at that point you should bite the bullet and spend $ 2 , 199 on a 15 - inch re ##tina mac ##book pro that offers the same storage space .
# that ' s why it ' s time to bite the bullet , suck it up and look to the future .
#
# Idiom usage word:  bullet
# Paraphrase word:  situation
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.6549312326643202
# literal_to_literal : 0.815031561586592
# fig_to_fig : 0.8666346073150635
# fig_to_paraphrase : 0.47785315692424774
# literal_to_paraphrase : 0.4762022074725893
# fig_to_random : 0.42879200902852144
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 11.09797543419732
# literal_to_literal : 7.970567146937053
# fig_to_fig : 6.959816312789917
# fig_to_paraphrase : 13.383568286895752
# literal_to_paraphrase : 13.198061847686768
# fig_to_random : 13.83554286956787
#
#
#
#
#
# Example 5
# Figurative phrases:
# i think i ' m going to hold on to it and maybe i ' ll find something to do with it later down the road .
# the goal may be a long way down the road , but the humanity ' s total command over nature should be ultimate aim .
# we support terrorist elements , most recently in syria and libya , but before that in iraq , bosnia , kosovo , and afghanistan , and then find ourselves fighting them down the road .
# who ' s going to pay for all of that free stuff down the road ?
# this problem has been kicked down the road long enough .
#
# Idiom usage word:  road
# Paraphrase word:  future
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.6193201820055644
# literal_to_literal : 0.7589576128456328
# fig_to_fig : 0.725439989566803
# fig_to_paraphrase : 0.48924335837364197
# literal_to_paraphrase : 0.46480182740423415
# fig_to_random : 0.45737734701898364
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 10.948673439025878
# literal_to_literal : 8.872811569107903
# fig_to_fig : 9.172696542739867
# fig_to_paraphrase : 12.844510803222656
# literal_to_paraphrase : 13.402289221021864
# fig_to_random : 13.012743186950683
#
#
#
#
#
# Example 6
# Figurative phrases:
# i think he has bigger fish to fry .
# jazz has bigger fish to fry than worrying whether her breasts are as big as her contemporaries .
# don ' t you have bigger fish to fry ?
# although this is an important subject , there are bigger fish to fry .
# americans are going to have far bigger fish to fry at home soon enough .
#
# Idiom usage word:  fish
# Paraphrase word:  problems
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.7634283357196384
# literal_to_literal : 0.8070428503884209
# fig_to_fig : 0.9144143104553223
# fig_to_paraphrase : 0.47748918294906617
# literal_to_paraphrase : 0.4461246344778273
# fig_to_random : 0.4265662062168121
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 9.048528660668268
# literal_to_literal : 7.639587587780422
# fig_to_fig : 5.527991271018982
# fig_to_paraphrase : 13.626378269195557
# literal_to_paraphrase : 13.228854688008626
# fig_to_random : 14.718009433746339
#
#
#
#
#
# Example 7
# Figurative phrases:
# lafayette , on the other hand , is one of the more culturally diverse cities i know .
# every minute of down ##time for a large site , on the other hand , could mean hundreds if not thousands of dollars in lost revenue .
# on the other hand , it is kind of distracting .
# samsung ' s hardware pioneering , on the other hand , needs more work .
# my husband , on the other hand , goes several times a week and doesn ' t like to miss it .
#
# Idiom usage word:  hand
# Paraphrase word:  perspective
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.49345805585384367
# literal_to_literal : 0.6568815231323242
# fig_to_fig : 0.8245088815689087
# fig_to_paraphrase : 0.5552750653690762
# literal_to_paraphrase : 0.4280410832828946
# fig_to_random : 0.4641613695356581
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 14.341928005218506
# literal_to_literal : 11.101163291931153
# fig_to_fig : 8.927928638458251
# fig_to_paraphrase : 13.169371541341146
# literal_to_paraphrase : 13.962405247158474
# fig_to_random : 14.450102933247884
#
#
#
#
#
# Example 8
# Figurative phrases:
# isn ' t the elephant in the room how the f he ' s typing without arms ?
# in the interview , cr ##ump described race as being the elephant in the room when it comes to the tray ##von case .
# there is a bit of an elephant in the room at the moment about the lack of openly the ##ist posters .
# let me first address the elephant in the room .
# this is the elephant in the room we ' ve all been waiting for , " burr ##is said .
#
# Idiom usage word:  elephant
# Paraphrase word:  unspoken
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.6677969363000658
# literal_to_literal : 0.8225974159108268
# fig_to_fig : 0.836800354719162
# fig_to_paraphrase : 0.4524363243579865
# literal_to_paraphrase : 0.43814966446823544
# fig_to_random : 0.44877760952169243
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 10.537639490763347
# literal_to_literal : 7.078897515932719
# fig_to_fig : 7.773522806167603
# fig_to_paraphrase : 13.593354320526123
# literal_to_paraphrase : 12.783304352230497
# fig_to_random : 13.666795522516423
#
#
#
#
#
# Example 9
# Figurative phrases:
# i feel like we ' re on the same page ; tho you ' re much further along in bad ##ass status .
# although anthony is doing all he can to improve his game , he must also make sure he is on the same page with his teammates .
# we can all try to get on the same page as far as what psalms , readings and collects to use .
# or you could let him know that you see marriage in your future and only want to date men who are on the same page .
# i think you and i are on the same page .
#
# Idiom usage word:  page
# Paraphrase word:  understanding
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.6003379199239943
# literal_to_literal : 0.6755004872878393
# fig_to_fig : 0.8368484139442444
# fig_to_paraphrase : 0.4341611671447754
# literal_to_paraphrase : 0.40954632196161483
# fig_to_random : 0.4686737583743201
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 12.173810980055068
# literal_to_literal : 11.039548092418247
# fig_to_fig : 7.745281171798706
# fig_to_paraphrase : 14.389811573028565
# literal_to_paraphrase : 14.815901226467556
# fig_to_random : 13.527544869316948
#
#
#
#
#
# Example 10
# Figurative phrases:
# and if you ' ve resort ##ed to name - calling , maybe you should just call it a day , as you have obviously run out of actual * arguments * .
# buy ' em off , and call it a day .
# rather than just return it and call it a day , i restored the device from scratch .
# i usually just call it a day , scout out the water or go for a hike .
# after a couple of hours of enjoying the surfing , without another soul in sight since this spot hardly ever has good waves , i was about to call it a day and go back home .
#
# Idiom usage word:  day
# Paraphrase word:  finish
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.6082178910573324
# literal_to_literal : 0.6560962514744865
# fig_to_fig : 0.8030423402786255
# fig_to_paraphrase : 0.38918552577495574
# literal_to_paraphrase : 0.45900104178322687
# fig_to_random : 0.393605806610801
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 12.509890916612413
# literal_to_literal : 11.571582476298014
# fig_to_fig : 8.98941421508789
# fig_to_paraphrase : 15.574852905273438
# literal_to_paraphrase : 14.487144554985894
# fig_to_random : 14.718289652737704
#
#
#
#
#
# Example 11
# Figurative phrases:
# why did you have to let the cat out of the bag like that ?
# i don ' t want to let the cat out of the bag yet , " he said .
# i ' m worried of not only causing discomfort for my dad , but also humiliation for my mom if annie decides to let the cat out of the bag .
# she didn ' t mean to let the cat out of the bag .
# the point was that once i let the cat out of the bag , the secret cease ##s to be a secret anymore and defeats more than one purpose .
#
# Idiom usage word:  cat
# Paraphrase word:  secret
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.8186240646574232
# literal_to_literal : 0.881085894174046
# fig_to_fig : 0.9443161845207214
# fig_to_paraphrase : 0.4840902870893478
# literal_to_paraphrase : 0.5367808659871419
# fig_to_random : 0.43477715373039244
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 7.676101758744982
# literal_to_literal : 6.256039460500081
# fig_to_fig : 4.232972717285156
# fig_to_paraphrase : 13.411495513916016
# literal_to_paraphrase : 12.750016890631782
# fig_to_random : 14.088514366149901

# %% [markdown]
# # BERT- BASE

# %%
# BERT- BASE 

word_args = {
   'comparison_type': 'words',
    'input': 'word_vec_sim_test.txt',
    'embedding_model': 'bert-base-uncased',
    'run_name': 'bert_base_1',
    'embedding_batch_size': 32,
    'embedding_cache': None,
#     'embedding_cache': 'cache/bert_base_1',
    'show_pca': True
}

run_vector_similarity.main(objectview(word_args))
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', description='Feature extraction', max=1, style=ProgressS…
# Example 0
# Figurative phrases:
# soon we ' re going to hit the sack .
# so if you ' re exercising close to bed ##time , calm down by med ##itating or doing a few gentle yoga poses before you hit the sack .
# would it be okay with you if we had a bite to eat now and hit the sack early ?
# i think i ' m gonna hit the sack before i get even more uncomfortable .
# but before you hit the sack , follow this expert advice for solving morning beauty emergencies .
#
# Idiom usage word:  sack
# Paraphrase word:  bed
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.45518295963605243
# literal_to_literal : 0.6645340902937783
# fig_to_fig : 0.8535900473594665
# fig_to_paraphrase : 0.2761309486627579
# literal_to_paraphrase : 0.33391864862706927
# fig_to_random : 0.2700047422539104
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 16.429634009467232
# literal_to_literal : 11.649292151133219
# fig_to_fig : 9.148036861419678
# fig_to_paraphrase : 19.518819007873535
# literal_to_paraphrase : 17.169565402136907
# fig_to_random : 19.33384121981534
#
#
#
#
#
# Example 1
# Figurative phrases:
# it ' s not always easy making decisions on the fly as a d ##m but here ' s what he probably should have done so that it wasn ' t obvious .
# that ' s a fairly advanced feature for any presentation device and requires a lot of computing power to do on the fly .
# but i certainly won ' t let them know i ' m t ##we ##aking things on the fly .
# operating on the fly , obama made a tough call and it seems like it was a good one .
# often these changes happened on the fly , daily , in response to sudden customer demand or customer loss .
#
# Idiom usage word:  fly
# Paraphrase word:  spontaneously
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.3900121249258518
# literal_to_literal : 0.6548756456800869
# fig_to_fig : 0.7225617408752442
# fig_to_paraphrase : 0.2309464606371793
# literal_to_paraphrase : 0.295597606761889
# fig_to_random : 0.2672271562947167
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 17.189074873924255
# literal_to_literal : 11.223891701017108
# fig_to_fig : 12.601115703582764
# fig_to_paraphrase : 19.169533469460227
# literal_to_paraphrase : 16.258528850295328
# fig_to_random : 18.795702828301323
#
#
#
#
#
# Example 2
# Figurative phrases:
# razor is aiming for that same market corner and they have set the bar rather high for it based on speculation .
# but apple has set the bar for magical technology and the iphone 5 failed to impress .
# take care not to set the bar too low - - - - low goals will not mo ##tiv ##ate you .
# it ' s worth noting for rams fans , though , that they set the bar insane ##ly high by hitting on so many rookie ##s .
# after it was released in 1998 , grim fan ##dan ##go blew everyone away and set the bar ridiculous ##ly high for adventure games .
#
# Idiom usage word:  bar
# Paraphrase word:  standard
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.472135900788837
# literal_to_literal : 0.7299918896622128
# fig_to_fig : 0.7844090223312378
# fig_to_paraphrase : 0.37161234974861146
# literal_to_paraphrase : 0.2689890772104263
# fig_to_random : 0.3274808637120507
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 15.499751853942872
# literal_to_literal : 11.247385501861572
# fig_to_fig : 9.751539134979248
# fig_to_paraphrase : 15.913637447357178
# literal_to_paraphrase : 17.43493201997545
# fig_to_random : 17.29414877458052
#
#
#
#
#
# Example 3
# Figurative phrases:
# i dunn ##o , what ' s the opportunity cost in the long run ?
# that marriage must be good for children is an argument that , by itself , can not pre ##va ##il in the attempt to preserve marriage in the long run .
# i would suggest buying your milk at grocery stores , in the long run you ' ll save money versus making multiple trips .
# in the long run , people buy from artists they trust .
# some organizations thrive for only a few quarters , but in the long run , they may be extremely unstable .
#
# Idiom usage word:  run
# Paraphrase word:  future
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.3217652519543966
# literal_to_literal : 0.5933951710661253
# fig_to_fig : 0.8422394514083862
# fig_to_paraphrase : 0.3656859663128853
# literal_to_paraphrase : 0.2773039388987753
# fig_to_random : 0.156831860045592
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 18.571379725138346
# literal_to_literal : 13.073371913697985
# fig_to_fig : 9.59664602279663
# fig_to_paraphrase : 18.020412101745606
# literal_to_paraphrase : 17.698440308041043
# fig_to_random : 20.204573016696507
#
#
#
#
#
# Example 4
# Figurative phrases:
# you ' re just going to have to bite the bullet and get through it .
# one possible response to this second example is to bite the bullet and to argue that from the point of view of fundamental physics , there really is no difference .
# like everything else in life , you ' re kind of just forced to bite the bullet and see the bigger picture .
# at that point you should bite the bullet and spend $ 2 , 199 on a 15 - inch re ##tina mac ##book pro that offers the same storage space .
# that ' s why it ' s time to bite the bullet , suck it up and look to the future .
#
# Idiom usage word:  bullet
# Paraphrase word:  situation
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.5115336436364386
# literal_to_literal : 0.6093573595086733
# fig_to_fig : 0.7999799251556396
# fig_to_paraphrase : 0.2612388703227043
# literal_to_paraphrase : 0.2795856863247334
# fig_to_random : 0.28674511096694255
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 15.643524339463976
# literal_to_literal : 13.059602684444851
# fig_to_fig : 10.401459312438964
# fig_to_paraphrase : 18.213960418701173
# literal_to_paraphrase : 16.992286745707194
# fig_to_random : 18.894603937322444
#
#
#
#
#
# Example 5
# Figurative phrases:
# i think i ' m going to hold on to it and maybe i ' ll find something to do with it later down the road .
# the goal may be a long way down the road , but the humanity ' s total command over nature should be ultimate aim .
# we support terrorist elements , most recently in syria and libya , but before that in iraq , bosnia , kosovo , and afghanistan , and then find ourselves fighting them down the road .
# who ' s going to pay for all of that free stuff down the road ?
# this problem has been kicked down the road long enough .
#
# Idiom usage word:  road
# Paraphrase word:  future
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.5530774136384328
# literal_to_literal : 0.6708070966932509
# fig_to_fig : 0.6840359330177307
# fig_to_paraphrase : 0.3446943286061287
# literal_to_paraphrase : 0.3243510761194759
# fig_to_random : 0.2905806336137984
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 13.97839298248291
# literal_to_literal : 11.167710251278347
# fig_to_fig : 12.370054626464844
# fig_to_paraphrase : 17.43082042694092
# literal_to_paraphrase : 16.669483153025308
# fig_to_random : 17.563092380099825
#
#
#
#
#
# Example 6
# Figurative phrases:
# i think he has bigger fish to fry .
# jazz has bigger fish to fry than worrying whether her breasts are as big as her contemporaries .
# don ' t you have bigger fish to fry ?
# although this is an important subject , there are bigger fish to fry .
# americans are going to have far bigger fish to fry at home soon enough .
#
# Idiom usage word:  fish
# Paraphrase word:  problems
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.7023938324716356
# literal_to_literal : 0.7030541135205163
# fig_to_fig : 0.8169949471950531
# fig_to_paraphrase : 0.2881389430165291
# literal_to_paraphrase : 0.2592485329343213
# fig_to_random : 0.25506464034318926
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 10.583382987976075
# literal_to_literal : 10.640876902474297
# fig_to_fig : 8.202838563919068
# fig_to_paraphrase : 16.338175067901613
# literal_to_paraphrase : 16.71275012758043
# fig_to_random : 17.770345458984377
#
#
#
#
#
# Example 7
# Figurative phrases:
# lafayette , on the other hand , is one of the more culturally diverse cities i know .
# every minute of down ##time for a large site , on the other hand , could mean hundreds if not thousands of dollars in lost revenue .
# on the other hand , it is kind of distracting .
# samsung ' s hardware pioneering , on the other hand , needs more work .
# my husband , on the other hand , goes several times a week and doesn ' t like to miss it .
#
# Idiom usage word:  hand
# Paraphrase word:  perspective
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.3304079440236092
# literal_to_literal : 0.5558276136716207
# fig_to_fig : 0.8517719984054566
# fig_to_paraphrase : 0.3537328730026881
# literal_to_paraphrase : 0.2952085104253557
# fig_to_random : 0.2031958219077852
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 18.249140586853027
# literal_to_literal : 13.5155211130778
# fig_to_fig : 9.210039949417114
# fig_to_paraphrase : 17.926549106174043
# literal_to_paraphrase : 17.136208735571966
# fig_to_random : 19.555821058485243
#
#
#
#
#
# Example 8
# Figurative phrases:
# isn ' t the elephant in the room how the f he ' s typing without arms ?
# in the interview , cr ##ump described race as being the elephant in the room when it comes to the tray ##von case .
# there is a bit of an elephant in the room at the moment about the lack of openly the ##ist posters .
# let me first address the elephant in the room .
# this is the elephant in the room we ' ve all been waiting for , " burr ##is said .
#
# Idiom usage word:  elephant
# Paraphrase word:  unspoken
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.5823585934109158
# literal_to_literal : 0.7246185855733024
# fig_to_fig : 0.7693457126617431
# fig_to_paraphrase : 0.34672622799873354
# literal_to_paraphrase : 0.31804326160086527
# fig_to_random : 0.25814051866531373
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 12.754688962300618
# literal_to_literal : 9.715674188401964
# fig_to_fig : 9.934475803375244
# fig_to_paraphrase : 15.915662002563476
# literal_to_paraphrase : 15.351682715945774
# fig_to_random : 18.246334400177002
#
#
#
#
#
# Example 9
# Figurative phrases:
# i feel like we ' re on the same page ; tho you ' re much further along in bad ##ass status .
# although anthony is doing all he can to improve his game , he must also make sure he is on the same page with his teammates .
# we can all try to get on the same page as far as what psalms , readings and collects to use .
# or you could let him know that you see marriage in your future and only want to date men who are on the same page .
# i think you and i are on the same page .
#
# Idiom usage word:  page
# Paraphrase word:  understanding
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.4975332942273882
# literal_to_literal : 0.5795615100198321
# fig_to_fig : 0.7553651392459869
# fig_to_paraphrase : 0.3886608248949051
# literal_to_paraphrase : 0.3072500354713864
# fig_to_random : 0.30844968882474033
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 14.854330762227375
# literal_to_literal : 12.98368657959832
# fig_to_fig : 10.657832527160645
# fig_to_paraphrase : 15.960609512329102
# literal_to_paraphrase : 16.276392777760822
# fig_to_random : 17.82809170809659
#
#
#
#
#
# Example 10
# Figurative phrases:
# and if you ' ve resort ##ed to name - calling , maybe you should just call it a day , as you have obviously run out of actual * arguments * .
# buy ' em off , and call it a day .
# rather than just return it and call it a day , i restored the device from scratch .
# i usually just call it a day , scout out the water or go for a hike .
# after a couple of hours of enjoying the surfing , without another soul in sight since this spot hardly ever has good waves , i was about to call it a day and go back home .
#
# Idiom usage word:  day
# Paraphrase word:  finish
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.5071577707926432
# literal_to_literal : 0.4836655482649803
# fig_to_fig : 0.8221547722816467
# fig_to_paraphrase : 0.3030741161108017
# literal_to_paraphrase : 0.29313248462147184
# fig_to_random : 0.27614339508793573
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 15.198493258158367
# literal_to_literal : 15.470258447859022
# fig_to_fig : 9.174462223052979
# fig_to_paraphrase : 17.39126663208008
# literal_to_paraphrase : 17.415021896362305
# fig_to_random : 18.265620387684216
#
#
#
#
#
# Example 11
# Figurative phrases:
# why did you have to let the cat out of the bag like that ?
# i don ' t want to let the cat out of the bag yet , " he said .
# i ' m worried of not only causing discomfort for my dad , but also humiliation for my mom if annie decides to let the cat out of the bag .
# she didn ' t mean to let the cat out of the bag .
# the point was that once i let the cat out of the bag , the secret cease ##s to be a secret anymore and defeats more than one purpose .
#
# Idiom usage word:  cat
# Paraphrase word:  secret
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.7601594991154141
# literal_to_literal : 0.7806152949730555
# fig_to_fig : 0.904816210269928
# fig_to_paraphrase : 0.31236143708229064
# literal_to_paraphrase : 0.30739231490426594
# fig_to_random : 0.3149607506665317
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 10.156921821170384
# literal_to_literal : 9.864700741238064
# fig_to_fig : 6.333431243896484
# fig_to_paraphrase : 17.367607250213624
# literal_to_paraphrase : 17.647701252831354
# fig_to_random : 17.267414127696643

# %% [markdown]
# # Fine-tuned on MRPC

# %%
# Fine-tuned on MRPC

word_args = {
   'comparison_type': 'words',
    'input': 'word_vec_sim_test.txt',
    'embedding_model': '../models/Exp1',
    'run_name': 'mrpc_1',
    'embedding_batch_size': 32,
    'embedding_cache': None,
#     'embedding_cache': 'cache/mrpc_1',
    'show_pca': True
}

run_vector_similarity.main(objectview(word_args))
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', description='Feature extraction', max=1, style=ProgressS…
# Example 0
# Figurative phrases:
# soon we ' re going to hit the sack .
# so if you ' re exercising close to bed ##time , calm down by med ##itating or doing a few gentle yoga poses before you hit the sack .
# would it be okay with you if we had a bite to eat now and hit the sack early ?
# i think i ' m gonna hit the sack before i get even more uncomfortable .
# but before you hit the sack , follow this expert advice for solving morning beauty emergencies .
#
# Idiom usage word:  sack
# Paraphrase word:  bed
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.5686284886466132
# literal_to_literal : 0.6579672561751472
# fig_to_fig : 0.8153275668621063
# fig_to_paraphrase : 0.5068623983860016
# literal_to_paraphrase : 0.49148702555232576
# fig_to_random : 0.4262173442542553
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 15.260562854342991
# literal_to_literal : 12.954627169503105
# fig_to_fig : 10.434338808059692
# fig_to_paraphrase : 16.600224113464357
# literal_to_paraphrase : 16.068759780459935
# fig_to_random : 17.71522159576416
#
#
#
#
#
# Example 1
# Figurative phrases:
# it ' s not always easy making decisions on the fly as a d ##m but here ' s what he probably should have done so that it wasn ' t obvious .
# that ' s a fairly advanced feature for any presentation device and requires a lot of computing power to do on the fly .
# but i certainly won ' t let them know i ' m t ##we ##aking things on the fly .
# operating on the fly , obama made a tough call and it seems like it was a good one .
# often these changes happened on the fly , daily , in response to sudden customer demand or customer loss .
#
# Idiom usage word:  fly
# Paraphrase word:  spontaneously
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.6573501661419868
# literal_to_literal : 0.7785523150648389
# fig_to_fig : 0.7060494184494018
# fig_to_paraphrase : 0.35799555651504883
# literal_to_paraphrase : 0.3525891156539067
# fig_to_random : 0.5494771248764462
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 13.59610435962677
# literal_to_literal : 10.304295028959002
# fig_to_fig : 12.834010410308839
# fig_to_paraphrase : 18.36916630484841
# literal_to_paraphrase : 17.62743295322765
# fig_to_random : 15.489249229431152
#
#
#
#
#
# Example 2
# Figurative phrases:
# razor is aiming for that same market corner and they have set the bar rather high for it based on speculation .
# but apple has set the bar for magical technology and the iphone 5 failed to impress .
# take care not to set the bar too low - - - - low goals will not mo ##tiv ##ate you .
# it ' s worth noting for rams fans , though , that they set the bar insane ##ly high by hitting on so many rookie ##s .
# after it was released in 1998 , grim fan ##dan ##go blew everyone away and set the bar ridiculous ##ly high for adventure games .
#
# Idiom usage word:  bar
# Paraphrase word:  standard
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.7104734169112311
# literal_to_literal : 0.7995282461245855
# fig_to_fig : 0.8147233605384827
# fig_to_paraphrase : 0.6416780099272728
# literal_to_paraphrase : 0.5982785950104396
# fig_to_random : 0.4649339014780708
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 12.59445537990994
# literal_to_literal : 10.252995517518785
# fig_to_fig : 10.259735202789306
# fig_to_paraphrase : 13.615076904296876
# literal_to_paraphrase : 14.2472105662028
# fig_to_random : 16.809686164855957
#
#
#
#
#
# Example 3
# Figurative phrases:
# i dunn ##o , what ' s the opportunity cost in the long run ?
# that marriage must be good for children is an argument that , by itself , can not pre ##va ##il in the attempt to preserve marriage in the long run .
# i would suggest buying your milk at grocery stores , in the long run you ' ll save money versus making multiple trips .
# in the long run , people buy from artists they trust .
# some organizations thrive for only a few quarters , but in the long run , they may be extremely unstable .
#
# Idiom usage word:  run
# Paraphrase word:  future
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.5118092589908176
# literal_to_literal : 0.684726819396019
# fig_to_fig : 0.741459584236145
# fig_to_paraphrase : 0.5220933139324189
# literal_to_paraphrase : 0.5343034449550841
# fig_to_random : 0.42174087199899885
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 16.374926884969074
# literal_to_literal : 12.613822566138374
# fig_to_fig : 12.376138401031493
# fig_to_paraphrase : 16.037650928497314
# literal_to_paraphrase : 15.166988309224447
# fig_to_random : 17.66476779513889
#
#
#
#
#
# Example 4
# Figurative phrases:
# you ' re just going to have to bite the bullet and get through it .
# one possible response to this second example is to bite the bullet and to argue that from the point of view of fundamental physics , there really is no difference .
# like everything else in life , you ' re kind of just forced to bite the bullet and see the bigger picture .
# at that point you should bite the bullet and spend $ 2 , 199 on a 15 - inch re ##tina mac ##book pro that offers the same storage space .
# that ' s why it ' s time to bite the bullet , suck it up and look to the future .
#
# Idiom usage word:  bullet
# Paraphrase word:  situation
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.684646283255683
# literal_to_literal : 0.7474615905019972
# fig_to_fig : 0.8621393501758575
# fig_to_paraphrase : 0.5386425699293613
# literal_to_paraphrase : 0.49697256452507443
# fig_to_random : 0.5766265726751751
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 13.328877766927084
# literal_to_literal : 11.456818991237217
# fig_to_fig : 9.110664653778077
# fig_to_paraphrase : 15.70491714477539
# literal_to_paraphrase : 15.791859934065076
# fig_to_random : 15.05106135474311
#
#
#
#
#
# Example 5
# Figurative phrases:
# i think i ' m going to hold on to it and maybe i ' ll find something to do with it later down the road .
# the goal may be a long way down the road , but the humanity ' s total command over nature should be ultimate aim .
# we support terrorist elements , most recently in syria and libya , but before that in iraq , bosnia , kosovo , and afghanistan , and then find ourselves fighting them down the road .
# who ' s going to pay for all of that free stuff down the road ?
# this problem has been kicked down the road long enough .
#
# Idiom usage word:  road
# Paraphrase word:  future
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.7658821052975124
# literal_to_literal : 0.7760151823361715
# fig_to_fig : 0.8452602624893188
# fig_to_paraphrase : 0.6326670145988464
# literal_to_paraphrase : 0.5868005765808953
# fig_to_random : 0.4870745157636702
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 11.280747010972764
# literal_to_literal : 10.65756924947103
# fig_to_fig : 9.425562620162964
# fig_to_paraphrase : 13.823011932373047
# literal_to_paraphrase : 14.250295596652562
# fig_to_random : 16.458433742523194
#
#
#
#
#
# Example 6
# Figurative phrases:
# i think he has bigger fish to fry .
# jazz has bigger fish to fry than worrying whether her breasts are as big as her contemporaries .
# don ' t you have bigger fish to fry ?
# although this is an important subject , there are bigger fish to fry .
# americans are going to have far bigger fish to fry at home soon enough .
#
# Idiom usage word:  fish
# Paraphrase word:  problems
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.7804128607114156
# literal_to_literal : 0.7979067911704382
# fig_to_fig : 0.8475118339061737
# fig_to_paraphrase : 0.6272173184156418
# literal_to_paraphrase : 0.6058339999781714
# fig_to_random : 0.46116741321980953
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 10.59951311747233
# literal_to_literal : 10.109530886014303
# fig_to_fig : 8.861155939102172
# fig_to_paraphrase : 13.630675926208497
# literal_to_paraphrase : 14.018513446384006
# fig_to_random : 16.513012981414796
#
#
#
#
#
# Example 7
# Figurative phrases:
# lafayette , on the other hand , is one of the more culturally diverse cities i know .
# every minute of down ##time for a large site , on the other hand , could mean hundreds if not thousands of dollars in lost revenue .
# on the other hand , it is kind of distracting .
# samsung ' s hardware pioneering , on the other hand , needs more work .
# my husband , on the other hand , goes several times a week and doesn ' t like to miss it .
#
# Idiom usage word:  hand
# Paraphrase word:  perspective
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.3604165176302195
# literal_to_literal : 0.4641902713260303
# fig_to_fig : 0.7328876405954361
# fig_to_paraphrase : 0.34643781466616524
# literal_to_paraphrase : 0.4079145093758901
# fig_to_random : 0.3242191196978092
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 18.782261085510253
# literal_to_literal : 16.37421622806125
# fig_to_fig : 12.353224658966065
# fig_to_paraphrase : 19.01122983296712
# literal_to_paraphrase : 17.291042147742377
# fig_to_random : 19.296783618927
#
#
#
#
#
# Example 8
# Figurative phrases:
# isn ' t the elephant in the room how the f he ' s typing without arms ?
# in the interview , cr ##ump described race as being the elephant in the room when it comes to the tray ##von case .
# there is a bit of an elephant in the room at the moment about the lack of openly the ##ist posters .
# let me first address the elephant in the room .
# this is the elephant in the room we ' ve all been waiting for , " burr ##is said .
#
# Idiom usage word:  elephant
# Paraphrase word:  unspoken
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.6648401465680864
# literal_to_literal : 0.7380896177556779
# fig_to_fig : 0.7691218137741089
# fig_to_paraphrase : 0.5278815102577209
# literal_to_paraphrase : 0.5335050973627302
# fig_to_random : 0.5121614780690935
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 13.223625628153483
# literal_to_literal : 11.145130965444777
# fig_to_fig : 11.37339506149292
# fig_to_paraphrase : 15.483512210845948
# literal_to_paraphrase : 14.687317943572998
# fig_to_random : 15.9602781507704
#
#
#
#
#
# Example 9
# Figurative phrases:
# i feel like we ' re on the same page ; tho you ' re much further along in bad ##ass status .
# although anthony is doing all he can to improve his game , he must also make sure he is on the same page with his teammates .
# we can all try to get on the same page as far as what psalms , readings and collects to use .
# or you could let him know that you see marriage in your future and only want to date men who are on the same page .
# i think you and i are on the same page .
#
# Idiom usage word:  page
# Paraphrase word:  understanding
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.623164427280426
# literal_to_literal : 0.6411601189110014
# fig_to_fig : 0.7540058434009552
# fig_to_paraphrase : 0.5110584309697151
# literal_to_paraphrase : 0.48359160903427334
# fig_to_random : 0.4526192037574947
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 14.18179259830051
# literal_to_literal : 13.492160969310337
# fig_to_fig : 11.812010192871094
# fig_to_paraphrase : 15.839626903533935
# literal_to_paraphrase : 15.98150463104248
# fig_to_random : 17.07493152618408
#
#
#
#
#
# Example 10
# Figurative phrases:
# and if you ' ve resort ##ed to name - calling , maybe you should just call it a day , as you have obviously run out of actual * arguments * .
# buy ' em off , and call it a day .
# rather than just return it and call it a day , i restored the device from scratch .
# i usually just call it a day , scout out the water or go for a hike .
# after a couple of hours of enjoying the surfing , without another soul in sight since this spot hardly ever has good waves , i was about to call it a day and go back home .
#
# Idiom usage word:  day
# Paraphrase word:  finish
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.574019500778781
# literal_to_literal : 0.48481097093058956
# fig_to_fig : 0.8594527006149292
# fig_to_paraphrase : 0.6479274505376815
# literal_to_paraphrase : 0.5057794948313838
# fig_to_random : 0.46814061373472216
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 15.09337141248915
# literal_to_literal : 16.26350094212426
# fig_to_fig : 9.027362394332886
# fig_to_paraphrase : 13.890748386383057
# literal_to_paraphrase : 15.655100462171767
# fig_to_random : 16.924505462646483
#
#
#
#
#
# Example 11
# Figurative phrases:
# why did you have to let the cat out of the bag like that ?
# i don ' t want to let the cat out of the bag yet , " he said .
# i ' m worried of not only causing discomfort for my dad , but also humiliation for my mom if annie decides to let the cat out of the bag .
# she didn ' t mean to let the cat out of the bag .
# the point was that once i let the cat out of the bag , the secret cease ##s to be a secret anymore and defeats more than one purpose .
#
# Idiom usage word:  cat
# Paraphrase word:  secret
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.74945670498742
# literal_to_literal : 0.7752453138430914
# fig_to_fig : 0.9111518025398254
# fig_to_paraphrase : 0.3910221573710442
# literal_to_paraphrase : 0.380779743525717
# fig_to_random : 0.5656062304973603
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 11.711010403103298
# literal_to_literal : 10.853294597731697
# fig_to_fig : 7.0723649024963375
# fig_to_paraphrase : 18.3891001701355
# literal_to_paraphrase : 18.10989680820041
# fig_to_random : 15.144699584113226

# %% [markdown]
# # Fine-tuned on our idiom data

# %%
# Fine-tuned on all our idiom data ALL

word_args = {
   'comparison_type': 'words',
    'input': 'word_vec_sim_test.txt',
    'embedding_model': '../models/Exp4',
    'run_name': 'idiom_all_1',
    'embedding_batch_size': 32,
    'embedding_cache': None,
#     'embedding_cache': 'cache/idiom_all_1',
    'show_pca': True
}

run_vector_similarity.main(objectview(word_args))
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', description='Feature extraction', max=1, style=ProgressS…
# Example 0
# Figurative phrases:
# soon we ' re going to hit the sack .
# so if you ' re exercising close to bed ##time , calm down by med ##itating or doing a few gentle yoga poses before you hit the sack .
# would it be okay with you if we had a bite to eat now and hit the sack early ?
# i think i ' m gonna hit the sack before i get even more uncomfortable .
# but before you hit the sack , follow this expert advice for solving morning beauty emergencies .
#
# Idiom usage word:  sack
# Paraphrase word:  bed
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.5756909297572241
# literal_to_literal : 0.7348951117859946
# fig_to_fig : 0.9118135511875153
# fig_to_paraphrase : 0.39350991666316987
# literal_to_paraphrase : 0.4041781703631083
# fig_to_random : 0.4728012323379517
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 13.088644451565212
# literal_to_literal : 9.707530193858677
# fig_to_fig : 6.353124332427979
# fig_to_paraphrase : 16.777843360900878
# literal_to_paraphrase : 15.888505872090658
# fig_to_random : 14.668717002868652
#
#
#
#
#
# Example 1
# Figurative phrases:
# it ' s not always easy making decisions on the fly as a d ##m but here ' s what he probably should have done so that it wasn ' t obvious .
# that ' s a fairly advanced feature for any presentation device and requires a lot of computing power to do on the fly .
# but i certainly won ' t let them know i ' m t ##we ##aking things on the fly .
# operating on the fly , obama made a tough call and it seems like it was a good one .
# often these changes happened on the fly , daily , in response to sudden customer demand or customer loss .
#
# Idiom usage word:  fly
# Paraphrase word:  spontaneously
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.5710415780544281
# literal_to_literal : 0.7345583651747022
# fig_to_fig : 0.8763074338436126
# fig_to_paraphrase : 0.3807294861836867
# literal_to_paraphrase : 0.4178521440110423
# fig_to_random : 0.44174231357044647
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 14.236403632164002
# literal_to_literal : 9.93183694566999
# fig_to_fig : 8.20965576171875
# fig_to_paraphrase : 16.9652756430886
# literal_to_paraphrase : 14.868614099242471
# fig_to_random : 15.842580604553223
#
#
#
#
#
# Example 2
# Figurative phrases:
# razor is aiming for that same market corner and they have set the bar rather high for it based on speculation .
# but apple has set the bar for magical technology and the iphone 5 failed to impress .
# take care not to set the bar too low - - - - low goals will not mo ##tiv ##ate you .
# it ' s worth noting for rams fans , though , that they set the bar insane ##ly high by hitting on so many rookie ##s .
# after it was released in 1998 , grim fan ##dan ##go blew everyone away and set the bar ridiculous ##ly high for adventure games .
#
# Idiom usage word:  bar
# Paraphrase word:  standard
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.5947506964206696
# literal_to_literal : 0.6878770457373725
# fig_to_fig : 0.8146197319030761
# fig_to_paraphrase : 0.5088476431369782
# literal_to_paraphrase : 0.4707090304957496
# fig_to_random : 0.510355004939166
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 12.536924701266818
# literal_to_literal : 10.619846092330086
# fig_to_fig : 8.635757350921631
# fig_to_paraphrase : 13.75555404663086
# literal_to_paraphrase : 13.907309309641521
# fig_to_random : 13.787524760853161
#
#
#
#
#
# Example 3
# Figurative phrases:
# i dunn ##o , what ' s the opportunity cost in the long run ?
# that marriage must be good for children is an argument that , by itself , can not pre ##va ##il in the attempt to preserve marriage in the long run .
# i would suggest buying your milk at grocery stores , in the long run you ' ll save money versus making multiple trips .
# in the long run , people buy from artists they trust .
# some organizations thrive for only a few quarters , but in the long run , they may be extremely unstable .
#
# Idiom usage word:  run
# Paraphrase word:  future
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.3133535285790761
# literal_to_literal : 0.6024297691053815
# fig_to_fig : 0.8995380580425263
# fig_to_paraphrase : 0.472441274523735
# literal_to_paraphrase : 0.30532410575283897
# fig_to_random : 0.3017202052474022
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 18.556938807169598
# literal_to_literal : 12.691506399048698
# fig_to_fig : 7.705247640609741
# fig_to_paraphrase : 16.56825122833252
# literal_to_paraphrase : 17.328350724114312
# fig_to_random : 18.788863258361815
#
#
#
#
#
# Example 4
# Figurative phrases:
# you ' re just going to have to bite the bullet and get through it .
# one possible response to this second example is to bite the bullet and to argue that from the point of view of fundamental physics , there really is no difference .
# like everything else in life , you ' re kind of just forced to bite the bullet and see the bigger picture .
# at that point you should bite the bullet and spend $ 2 , 199 on a 15 - inch re ##tina mac ##book pro that offers the same storage space .
# that ' s why it ' s time to bite the bullet , suck it up and look to the future .
#
# Idiom usage word:  bullet
# Paraphrase word:  situation
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.6877829644415113
# literal_to_literal : 0.7619138111670812
# fig_to_fig : 0.8606392979621887
# fig_to_paraphrase : 0.41614282071590425
# literal_to_paraphrase : 0.41016295817163256
# fig_to_random : 0.4871215739033439
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 11.37601769765218
# literal_to_literal : 10.029053303930494
# fig_to_fig : 7.455565309524536
# fig_to_paraphrase : 14.862956790924072
# literal_to_paraphrase : 15.160031202104356
# fig_to_random : 14.08519401550293
#
#
#
#
#
# Example 5
# Figurative phrases:
# i think i ' m going to hold on to it and maybe i ' ll find something to do with it later down the road .
# the goal may be a long way down the road , but the humanity ' s total command over nature should be ultimate aim .
# we support terrorist elements , most recently in syria and libya , but before that in iraq , bosnia , kosovo , and afghanistan , and then find ourselves fighting them down the road .
# who ' s going to pay for all of that free stuff down the road ?
# this problem has been kicked down the road long enough .
#
# Idiom usage word:  road
# Paraphrase word:  future
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.7020993192990621
# literal_to_literal : 0.6867283682028452
# fig_to_fig : 0.864328795671463
# fig_to_paraphrase : 0.3503317797183991
# literal_to_paraphrase : 0.360322428908613
# fig_to_random : 0.4303846997022629
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 10.65881281958686
# literal_to_literal : 10.46750028928121
# fig_to_fig : 7.520429897308349
# fig_to_paraphrase : 16.84819236755371
# literal_to_paraphrase : 16.105601660410564
# fig_to_random : 15.43157829284668
#
#
#
#
#
# Example 6
# Figurative phrases:
# i think he has bigger fish to fry .
# jazz has bigger fish to fry than worrying whether her breasts are as big as her contemporaries .
# don ' t you have bigger fish to fry ?
# although this is an important subject , there are bigger fish to fry .
# americans are going to have far bigger fish to fry at home soon enough .
#
# Idiom usage word:  fish
# Paraphrase word:  problems
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.625015856160058
# literal_to_literal : 0.7435248725944095
# fig_to_fig : 0.9114291548728943
# fig_to_paraphrase : 0.29790023803710936
# literal_to_paraphrase : 0.38748403357134925
# fig_to_random : 0.3411575049161911
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 12.97177268134223
# literal_to_literal : 9.771914707289802
# fig_to_fig : 6.577225089073181
# fig_to_paraphrase : 17.56604679107666
# literal_to_paraphrase : 15.02138245900472
# fig_to_random : 17.52066080093384
#
#
#
#
#
# Example 7
# Figurative phrases:
# lafayette , on the other hand , is one of the more culturally diverse cities i know .
# every minute of down ##time for a large site , on the other hand , could mean hundreds if not thousands of dollars in lost revenue .
# on the other hand , it is kind of distracting .
# samsung ' s hardware pioneering , on the other hand , needs more work .
# my husband , on the other hand , goes several times a week and doesn ' t like to miss it .
#
# Idiom usage word:  hand
# Paraphrase word:  perspective
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.5417277789115906
# literal_to_literal : 0.6244841701454587
# fig_to_fig : 0.9282412052154541
# fig_to_paraphrase : 0.2908654610315959
# literal_to_paraphrase : 0.3255614181359609
# fig_to_random : 0.4054611855083042
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 14.433019695281983
# literal_to_literal : 12.860674497816298
# fig_to_fig : 5.779073858261109
# fig_to_paraphrase : 18.197161377800835
# literal_to_paraphrase : 17.49131351047092
# fig_to_random : 15.56317827436659
#
#
#
#
#
# Example 8
# Figurative phrases:
# isn ' t the elephant in the room how the f he ' s typing without arms ?
# in the interview , cr ##ump described race as being the elephant in the room when it comes to the tray ##von case .
# there is a bit of an elephant in the room at the moment about the lack of openly the ##ist posters .
# let me first address the elephant in the room .
# this is the elephant in the room we ' ve all been waiting for , " burr ##is said .
#
# Idiom usage word:  elephant
# Paraphrase word:  unspoken
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.6965905547142028
# literal_to_literal : 0.7741264320082135
# fig_to_fig : 0.8648573756217957
# fig_to_paraphrase : 0.486457422375679
# literal_to_paraphrase : 0.4816414929098553
# fig_to_random : 0.4282736864686012
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 10.115911102294922
# literal_to_literal : 8.744213488366869
# fig_to_fig : 6.660358810424805
# fig_to_paraphrase : 13.255309886932373
# literal_to_paraphrase : 13.425678782992893
# fig_to_random : 14.679963607788086
#
#
#
#
#
# Example 9
# Figurative phrases:
# i feel like we ' re on the same page ; tho you ' re much further along in bad ##ass status .
# although anthony is doing all he can to improve his game , he must also make sure he is on the same page with his teammates .
# we can all try to get on the same page as far as what psalms , readings and collects to use .
# or you could let him know that you see marriage in your future and only want to date men who are on the same page .
# i think you and i are on the same page .
#
# Idiom usage word:  page
# Paraphrase word:  understanding
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.6252903521060944
# literal_to_literal : 0.663946196436882
# fig_to_fig : 0.9109485805034637
# fig_to_paraphrase : 0.32365143328905105
# literal_to_paraphrase : 0.3997062686416838
# fig_to_random : 0.3759866747260094
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 11.776242023044162
# literal_to_literal : 11.185773770014444
# fig_to_fig : 5.648507928848266
# fig_to_paraphrase : 15.994769191741943
# literal_to_paraphrase : 15.150811990102133
# fig_to_random : 15.649897708892823
#
#
#
#
#
# Example 10
# Figurative phrases:
# and if you ' ve resort ##ed to name - calling , maybe you should just call it a day , as you have obviously run out of actual * arguments * .
# buy ' em off , and call it a day .
# rather than just return it and call it a day , i restored the device from scratch .
# i usually just call it a day , scout out the water or go for a hike .
# after a couple of hours of enjoying the surfing , without another soul in sight since this spot hardly ever has good waves , i was about to call it a day and go back home .
#
# Idiom usage word:  day
# Paraphrase word:  finish
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.5095486462116241
# literal_to_literal : 0.6638303051392237
# fig_to_fig : 0.9014366209506989
# fig_to_paraphrase : 0.3514300924539566
# literal_to_paraphrase : 0.39011418372392653
# fig_to_random : 0.3868725763426887
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 15.17638316684299
# literal_to_literal : 12.585432079103258
# fig_to_fig : 6.738125658035278
# fig_to_paraphrase : 16.481911659240723
# literal_to_paraphrase : 16.15488616095649
# fig_to_random : 15.688317171732585
#
#
#
#
#
# Example 11
# Figurative phrases:
# why did you have to let the cat out of the bag like that ?
# i don ' t want to let the cat out of the bag yet , " he said .
# i ' m worried of not only causing discomfort for my dad , but also humiliation for my mom if annie decides to let the cat out of the bag .
# she didn ' t mean to let the cat out of the bag .
# the point was that once i let the cat out of the bag , the secret cease ##s to be a secret anymore and defeats more than one purpose .
#
# Idiom usage word:  cat
# Paraphrase word:  secret
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.7977396236525641
# literal_to_literal : 0.8033052682876587
# fig_to_fig : 0.9473800182342529
# fig_to_paraphrase : 0.42527043640613554
# literal_to_paraphrase : 0.4290376964542601
# fig_to_random : 0.5172943256118081
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 8.494810676574707
# literal_to_literal : 8.394815908537971
# fig_to_fig : 4.30205807685852
# fig_to_paraphrase : 15.69832706451416
# literal_to_paraphrase : 15.678191704220241
# fig_to_random : 13.247187267650258

# %%
# BERT - LARGE

sent_args = {
   'comparison_type': 'para_pairs',
    'input': '../probe/output/daniel/train_classifications.tsv',
    'embedding_model': 'bert-large-uncased',
    'run_name': 'paraphrase_large_test',
    'embedding_batch_size': 16,
    'embedding_cache': 'paraphrase_large_test'
}

# main(objectview(sent_args))

# %%
sent_args = {
   'comparison_type': 'para_pairs',
    'input': '../probe/output/daniel/train_classifications.tsv',
    'embedding_model': 'bert-large-uncased',
    'run_name': 'paraphrase_large_test',
    'embedding_batch_size': 16,
    'embedding_cache': 'cache/paraphrase_large_test'
}

# main(objectview(sent_args))
