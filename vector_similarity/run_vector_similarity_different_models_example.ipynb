# %%
import run_vector_similarity

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
class objectview(object):
    def __init__(self, d):
        self.__dict__ = d

# %% [markdown]
# #  BERT - LARGE

# %%
# BERT - LARGE

word_args = {
   'comparison_type': 'words',
    'input': 'word_vec_sim_test.txt',
    'embedding_model': 'bert-large-uncased',
    'run_name': 'word_large_1',
    'embedding_batch_size': 32,
    'embedding_cache': 'cache/word_large_1',
    'show_pca': True
}

run_vector_similarity.main(objectview(word_args))
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): s3.amazonaws.com:443
# DEBUG:urllib3.connectionpool:https://s3.amazonaws.com:443 "HEAD /models.huggingface.co/bert/bert-large-uncased-vocab.txt HTTP/1.1" 200 0
# INFO:transformers.tokenization_utils:loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-large-uncased-vocab.txt from cache at /Users/paigefink/.cache/torch/transformers/9b3c03a36e83b13d5ba95ac965c9f9074a99e14340c523ab405703179e79fc46.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# INFO:data_loading:Loading embedding data from cache/word_large_1...
# INFO:data_loading:Loading sentences.pt from cache/word_large_1
# INFO:data_loading:Loading inputs.pt from cache/word_large_1
# INFO:data_loading:Loading indices.pt from cache/word_large_1
# INFO:data_loading:Loading pools.pt from cache/word_large_1
# Example 0
# Figurative phrases:
# soon we ' re going to hit the sack .
# so if you ' re exercising close to bed ##time , calm down by med ##itating or doing a few gentle yoga poses before you hit the sack .
# would it be okay with you if we had a bite to eat now and hit the sack early ?
# i think i ' m gonna hit the sack before i get even more uncomfortable .
# but before you hit the sack , follow this expert advice for solving morning beauty emergencies .
#
# Idiom usage word:  sack
# Paraphrase word:  bed
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.5078671508365207
# literal_to_literal : 0.7760081407096651
# fig_to_fig : 0.7589948058128357
# fig_to_paraphrase : 0.455306636095047
# literal_to_paraphrase : 0.4630802750587463
# fig_to_random : 0.45725299499251626
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 12.871600045098198
# literal_to_literal : 8.766190078523424
# fig_to_fig : 8.801383209228515
# fig_to_paraphrase : 13.97687313079834
# literal_to_paraphrase : 14.01913865407308
# fig_to_random : 13.06278093511408
#
#
#
#
#
# Example 1
# Figurative phrases:
# it ' s not always easy making decisions on the fly as a d ##m but here ' s what he probably should have done so that it wasn ' t obvious .
# that ' s a fairly advanced feature for any presentation device and requires a lot of computing power to do on the fly .
# but i certainly won ' t let them know i ' m t ##we ##aking things on the fly .
# operating on the fly , obama made a tough call and it seems like it was a good one .
# often these changes happened on the fly , daily , in response to sudden customer demand or customer loss .
#
# Idiom usage word:  fly
# Paraphrase word:  spontaneously
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.5233455263078213
# literal_to_literal : 0.6911123735564095
# fig_to_fig : 0.7300763726234436
# fig_to_paraphrase : 0.4885933843525973
# literal_to_paraphrase : 0.4055443304506215
# fig_to_random : 0.47493265536096363
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 13.374811935424805
# literal_to_literal : 10.407371946743556
# fig_to_fig : 10.18589096069336
# fig_to_paraphrase : 13.609188704057173
# literal_to_paraphrase : 14.244095758958297
# fig_to_random : 13.76808673010932
#
#
#
#
#
# Example 2
# Figurative phrases:
# razor is aiming for that same market corner and they have set the bar rather high for it based on speculation .
# but apple has set the bar for magical technology and the iphone 5 failed to impress .
# take care not to set the bar too low - - - - low goals will not mo ##tiv ##ate you .
# it ' s worth noting for rams fans , though , that they set the bar insane ##ly high by hitting on so many rookie ##s .
# after it was released in 1998 , grim fan ##dan ##go blew everyone away and set the bar ridiculous ##ly high for adventure games .
#
# Idiom usage word:  bar
# Paraphrase word:  standard
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.5169897397359212
# literal_to_literal : 0.8094712545474371
# fig_to_fig : 0.8359665513038635
# fig_to_paraphrase : 0.48567103981971743
# literal_to_paraphrase : 0.4168248640166389
# fig_to_random : 0.3853063874774509
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 13.899271265665691
# literal_to_literal : 7.952579021453857
# fig_to_fig : 8.70262770652771
# fig_to_paraphrase : 14.385706424713135
# literal_to_paraphrase : 13.88931318918864
# fig_to_random : 15.592806604173449
#
#
#
#
#
# Example 3
# Figurative phrases:
# i dunn ##o , what ' s the opportunity cost in the long run ?
# that marriage must be good for children is an argument that , by itself , can not pre ##va ##il in the attempt to preserve marriage in the long run .
# i would suggest buying your milk at grocery stores , in the long run you ' ll save money versus making multiple trips .
# in the long run , people buy from artists they trust .
# some organizations thrive for only a few quarters , but in the long run , they may be extremely unstable .
#
# Idiom usage word:  run
# Paraphrase word:  future
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.4953496098518372
# literal_to_literal : 0.7137141070432134
# fig_to_fig : 0.7929155468940735
# fig_to_paraphrase : 0.5862216472625732
# literal_to_paraphrase : 0.42573184967041017
# fig_to_random : 0.4418427354097366
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 14.23606334262424
# literal_to_literal : 10.233065101835463
# fig_to_fig : 9.518894863128661
# fig_to_paraphrase : 12.69523811340332
# literal_to_paraphrase : 14.327840921613905
# fig_to_random : 15.014237060546876
#
#
#
#
#
# Example 4
# Figurative phrases:
# you ' re just going to have to bite the bullet and get through it .
# one possible response to this second example is to bite the bullet and to argue that from the point of view of fundamental physics , there really is no difference .
# like everything else in life , you ' re kind of just forced to bite the bullet and see the bigger picture .
# at that point you should bite the bullet and spend $ 2 , 199 on a 15 - inch re ##tina mac ##book pro that offers the same storage space .
# that ' s why it ' s time to bite the bullet , suck it up and look to the future .
#
# Idiom usage word:  bullet
# Paraphrase word:  situation
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.6549312154452006
# literal_to_literal : 0.815031561586592
# fig_to_fig : 0.8666345715522766
# fig_to_paraphrase : 0.47785313248634337
# literal_to_paraphrase : 0.4762022074725893
# fig_to_random : 0.45607731077406144
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 11.097975561353895
# literal_to_literal : 7.970567146937053
# fig_to_fig : 6.959816265106201
# fig_to_paraphrase : 13.383568496704102
# literal_to_paraphrase : 13.198061847686768
# fig_to_random : 13.719813876681858
#
#
#
#
#
# Example 5
# Figurative phrases:
# i think i ' m going to hold on to it and maybe i ' ll find something to do with it later down the road .
# the goal may be a long way down the road , but the humanity ' s total command over nature should be ultimate aim .
# we support terrorist elements , most recently in syria and libya , but before that in iraq , bosnia , kosovo , and afghanistan , and then find ourselves fighting them down the road .
# who ' s going to pay for all of that free stuff down the road ?
# this problem has been kicked down the road long enough .
#
# Idiom usage word:  road
# Paraphrase word:  future
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.6193201820055644
# literal_to_literal : 0.7589576128456328
# fig_to_fig : 0.725439989566803
# fig_to_paraphrase : 0.48924334049224855
# literal_to_paraphrase : 0.46480181084738836
# fig_to_random : 0.450595806945454
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 10.948673439025878
# literal_to_literal : 8.872811569107903
# fig_to_fig : 9.172696542739867
# fig_to_paraphrase : 12.844511394500733
# literal_to_paraphrase : 13.40228983561198
# fig_to_random : 12.848466248945757
#
#
#
#
#
# Example 6
# Figurative phrases:
# i think he has bigger fish to fry .
# jazz has bigger fish to fry than worrying whether her breasts are as big as her contemporaries .
# don ' t you have bigger fish to fry ?
# although this is an important subject , there are bigger fish to fry .
# americans are going to have far bigger fish to fry at home soon enough .
#
# Idiom usage word:  fish
# Paraphrase word:  problems
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.7634283317459954
# literal_to_literal : 0.8070428503884209
# fig_to_fig : 0.9144143104553223
# fig_to_paraphrase : 0.47748918294906617
# literal_to_paraphrase : 0.4461246331532796
# fig_to_random : 0.4265662062168121
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 9.048528734842936
# literal_to_literal : 7.639587614271376
# fig_to_fig : 5.527991271018982
# fig_to_paraphrase : 13.626378269195557
# literal_to_paraphrase : 13.228854677412246
# fig_to_random : 14.718009433746339
#
#
#
#
#
# Example 7
# Figurative phrases:
# lafayette , on the other hand , is one of the more culturally diverse cities i know .
# every minute of down ##time for a large site , on the other hand , could mean hundreds if not thousands of dollars in lost revenue .
# on the other hand , it is kind of distracting .
# samsung ' s hardware pioneering , on the other hand , needs more work .
# my husband , on the other hand , goes several times a week and doesn ' t like to miss it .
#
# Idiom usage word:  hand
# Paraphrase word:  perspective
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.49345805585384367
# literal_to_literal : 0.6568815231323242
# fig_to_fig : 0.8245088815689087
# fig_to_paraphrase : 0.5552750647068023
# literal_to_paraphrase : 0.42804108593198986
# fig_to_random : 0.48162908732891085
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 14.341928005218506
# literal_to_literal : 11.101163291931153
# fig_to_fig : 8.927928638458251
# fig_to_paraphrase : 13.169371435377332
# literal_to_paraphrase : 13.962405109405518
# fig_to_random : 14.644084281921387
#
#
#
#
#
# Example 8
# Figurative phrases:
# isn ' t the elephant in the room how the f he ' s typing without arms ?
# in the interview , cr ##ump described race as being the elephant in the room when it comes to the tray ##von case .
# there is a bit of an elephant in the room at the moment about the lack of openly the ##ist posters .
# let me first address the elephant in the room .
# this is the elephant in the room we ' ve all been waiting for , " burr ##is said .
#
# Idiom usage word:  elephant
# Paraphrase word:  unspoken
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.6677969415982564
# literal_to_literal : 0.8225974241892496
# fig_to_fig : 0.836800354719162
# fig_to_paraphrase : 0.4524363243579865
# literal_to_paraphrase : 0.43814966413709855
# fig_to_random : 0.44877760952169243
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 10.537639511956108
# literal_to_literal : 7.078897515932719
# fig_to_fig : 7.773522806167603
# fig_to_paraphrase : 13.593354320526123
# literal_to_paraphrase : 12.783304362826877
# fig_to_random : 13.666795522516423
#
#
#
#
#
# Example 9
# Figurative phrases:
# i feel like we ' re on the same page ; tho you ' re much further along in bad ##ass status .
# although anthony is doing all he can to improve his game , he must also make sure he is on the same page with his teammates .
# we can all try to get on the same page as far as what psalms , readings and collects to use .
# or you could let him know that you see marriage in your future and only want to date men who are on the same page .
# i think you and i are on the same page .
#
# Idiom usage word:  page
# Paraphrase word:  understanding
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.6003379199239943
# literal_to_literal : 0.6755004872878393
# fig_to_fig : 0.8368484139442444
# fig_to_paraphrase : 0.4341611611843109
# literal_to_paraphrase : 0.40954631202750735
# fig_to_random : 0.4686737583743201
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 12.173810980055068
# literal_to_literal : 11.039548092418247
# fig_to_fig : 7.745281171798706
# fig_to_paraphrase : 14.389811706542968
# literal_to_paraphrase : 14.815901353624131
# fig_to_random : 13.527544869316948
#
#
#
#
#
# Example 10
# Figurative phrases:
# and if you ' ve resort ##ed to name - calling , maybe you should just call it a day , as you have obviously run out of actual * arguments * .
# buy ' em off , and call it a day .
# rather than just return it and call it a day , i restored the device from scratch .
# i usually just call it a day , scout out the water or go for a hike .
# after a couple of hours of enjoying the surfing , without another soul in sight since this spot hardly ever has good waves , i was about to call it a day and go back home .
#
# Idiom usage word:  day
# Paraphrase word:  finish
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.6082178705268436
# literal_to_literal : 0.6560962481631173
# fig_to_fig : 0.8030422985553741
# fig_to_paraphrase : 0.3891855174303055
# literal_to_paraphrase : 0.45900104608800674
# fig_to_random : 0.3726095113489363
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 12.509890810648601
# literal_to_literal : 11.571582555770874
# fig_to_fig : 8.989413928985595
# fig_to_paraphrase : 15.574852485656738
# literal_to_paraphrase : 14.487144597371419
# fig_to_random : 15.189256159464518
#
#
#
#
#
# Example 11
# Figurative phrases:
# why did you have to let the cat out of the bag like that ?
# i don ' t want to let the cat out of the bag yet , " he said .
# i ' m worried of not only causing discomfort for my dad , but also humiliation for my mom if annie decides to let the cat out of the bag .
# she didn ' t mean to let the cat out of the bag .
# the point was that once i let the cat out of the bag , the secret cease ##s to be a secret anymore and defeats more than one purpose .
#
# Idiom usage word:  cat
# Paraphrase word:  secret
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.8186240805519952
# literal_to_literal : 0.881085894174046
# fig_to_fig : 0.9443162202835083
# fig_to_paraphrase : 0.48409029066562653
# literal_to_paraphrase : 0.5367808659871419
# fig_to_random : 0.4626228939403187
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 7.676101207733154
# literal_to_literal : 6.256039460500081
# fig_to_fig : 4.232971715927124
# fig_to_paraphrase : 13.411495246887206
# literal_to_paraphrase : 12.750016890631782
# fig_to_random : 12.940916911038485

# %% [markdown]
# # BERT- BASE

# %%
# BERT- BASE 

word_args = {
   'comparison_type': 'words',
    'input': 'word_vec_sim_test.txt',
    'embedding_model': 'bert-base-uncased',
    'run_name': 'word_base_test',
    'embedding_batch_size': 16,
#     'embedding_cache': None,
    'embedding_cache': 'cache/word_base_test',
    'show_pca': True
}

run_vector_similarity.main(objectview(word_args))

# %% [markdown]
# # Fine-tuned on MRPC

# %%
# Fine-tuned on MRPC

word_args = {
   'comparison_type': 'words',
    'input': 'word_vec_sim_test.txt',
    'embedding_model': 'models/mrpc',
    'run_name': 'mrcp_1',
    'embedding_batch_size': 32,
#     'embedding_cache': None,
    'embedding_cache': 'cache/mrpc_1',
    'show_pca': True
}

run_vector_similarity.main(objectview(word_args))
# Out:
# Example 0
# Figurative phrases:
# soon we ' re going to hit the sack .
# so if you ' re ex ##er ##cis ##ing close to bed ##time , calm down by me ##dit ##ating or doing a few gentle yoga poses before you hit the sack .
# would it be okay with you if we had a bite to eat now and hit the sack early ?
# i think i ' m gonna hit the sack before i get even more uncomfortable .
# but before you hit the sack , follow this expert advice for solving morning beauty emerge ##ncies .
#
# Idiom usage word:  sack
# Paraphrase word:  bed
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.6748070120811462
# literal_to_literal : 0.8055495305193795
# fig_to_fig : 0.8604310274124145
# fig_to_paraphrase : 0.5737834680080414
# literal_to_paraphrase : 0.5977587232987086
# fig_to_random : 0.5330432212352753
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 11.193059073554146
# literal_to_literal : 8.415265083312988
# fig_to_fig : 7.47610993385315
# fig_to_paraphrase : 12.935738258361816
# literal_to_paraphrase : 12.250966654883491
# fig_to_random : 13.739756011962891
#
#
#
#
#
# Example 1
# Figurative phrases:
# it ' s not always easy making decisions on the fly as a d ##m but here ' s what he probably should have done so that it wasn ' t obvious .
# that ' s a fairly advanced feature for any presentation device and requires a lot of computing power to do on the fly .
# but i certainly won ' t let them know i ' m t ##we ##aking things on the fly .
# operating on the fly , o ##ba ##ma made a tough call and it seems like it was a good one .
# often these changes happened on the fly , daily , in response to sudden customer demand or customer loss .
#
# Idiom usage word:  fly
# Paraphrase word:  spontaneous
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.6032847732305526
# literal_to_literal : 0.7750273644924164
# fig_to_fig : 0.8270131468772888
# fig_to_paraphrase : 0.5084209664301439
# literal_to_paraphrase : 0.5815221196548506
# fig_to_random : 0.5302897830804189
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 12.721004128456116
# literal_to_literal : 8.916377220835004
# fig_to_fig : 8.78817777633667
# fig_to_paraphrase : 14.124362720142711
# literal_to_paraphrase : 12.266007835214788
# fig_to_random : 13.888029713100858
#
#
#
#
#
# Example 2
# Figurative phrases:
# razor is aiming for that same market corner and they have set the bar rather high for it based on speculation .
# but apple has set the bar for magical technology and the i ##phone 5 failed to impress .
# take care not to set the bar too low - - - - low goals will not m ##ot ##ivate you .
# it ' s worth noting for ram ##s fans , though , that they set the bar insane ##ly high by hitting on so many rookie ##s .
# after it was released in 1998 , grim fan ##dan ##go blew everyone away and set the bar ridiculous ##ly high for adventure games .
#
# Idiom usage word:  bar
# Paraphrase word:  standard
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.7080671972698636
# literal_to_literal : 0.8149321873982748
# fig_to_fig : 0.8329885959625244
# fig_to_paraphrase : 0.6294458901882172
# literal_to_paraphrase : 0.5781958132982254
# fig_to_random : 0.5933027148246766
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 10.703968408372667
# literal_to_literal : 8.469344112608168
# fig_to_fig : 8.157716941833495
# fig_to_paraphrase : 11.829168033599853
# literal_to_paraphrase : 12.546345795525445
# fig_to_random : 12.484145312839084
#
#
#
#
#
# Example 3
# Figurative phrases:
# i du ##nn ##o , what ' s the opportunity cost in the long run ?
# that marriage must be good for children is an argument that , by itself , can not pre ##va ##il in the attempt to preserve marriage in the long run .
# i would suggest buying your milk at grocery stores , in the long run you ' ll save money versus making multiple trips .
# in the long run , people buy from artists they trust .
# some organizations th ##rive for only a few quarters , but in the long run , they may be extremely unstable .
#
# Idiom usage word:  run
# Paraphrase word:  future
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.477223449283176
# literal_to_literal : 0.7464613533682294
# fig_to_fig : 0.8347967624664306
# fig_to_paraphrase : 0.4955556046962738
# literal_to_paraphrase : 0.5520845548974143
# fig_to_random : 0.4526457645676353
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 15.918320062425401
# literal_to_literal : 9.648337854279411
# fig_to_fig : 9.76262550354004
# fig_to_paraphrase : 15.808729877471924
# literal_to_paraphrase : 13.145376502143012
# fig_to_random : 16.169005740772594
#
#
#
#
#
# Example 4
# Figurative phrases:
# you ' re just going to have to bite the bullet and get through it .
# one possible response to this second example is to bite the bullet and to argue that from the point of view of fundamental physics , there really is no difference .
# like everything else in life , you ' re kind of just forced to bite the bullet and see the bigger picture .
# at that point you should bite the bullet and spend $ 2 , 199 on a 15 - inch re ##tina mac ##book pro that offers the same storage space .
# that ' s why it ' s time to bite the bullet , suck it up and look to the future .
#
# Idiom usage word:  bullet
# Paraphrase word:  situation
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.7100754512680901
# literal_to_literal : 0.7395948626928859
# fig_to_fig : 0.8761902868747711
# fig_to_paraphrase : 0.6214925980567932
# literal_to_paraphrase : 0.5930831457177798
# fig_to_random : 0.6008115204897794
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 10.319995594024657
# literal_to_literal : 9.786869605382284
# fig_to_fig : 6.605716371536255
# fig_to_paraphrase : 11.472238006591796
# literal_to_paraphrase : 12.204973390367297
# fig_to_random : 11.92467562935569
#
#
#
#
#
# Example 5
# Figurative phrases:
# i think i ' m going to hold on to it and maybe i ' ll find something to do with it later down the road .
# the goal may be a long way down the road , but the humanity ' s total command over nature should be ultimate aim .
# we support terrorist elements , most recently in s ##yr ##ia and l ##ib ##ya , but before that in i ##ra ##q , b ##os ##nia , k ##oso ##vo , and a ##f ##ghan ##istan , and then find ourselves fighting them down the road .
# who ' s going to pay for all of that free stuff down the road ?
# this problem has been kicked down the road long enough .
#
# Idiom usage word:  road
# Paraphrase word:  future
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.7371659278869629
# literal_to_literal : 0.7918163471751742
# fig_to_fig : 0.8116727590560913
# fig_to_paraphrase : 0.5865160554647446
# literal_to_paraphrase : 0.5656259649329716
# fig_to_random : 0.6186438928950917
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 9.813990084330241
# literal_to_literal : 8.64639699459076
# fig_to_fig : 8.381593322753906
# fig_to_paraphrase : 12.646615695953368
# literal_to_paraphrase : 12.85089274512397
# fig_to_random : 11.80542101426558
#
#
#
#
#
# Example 6
# Figurative phrases:
# i think he has bigger fish to f ##ry .
# jazz has bigger fish to f ##ry than worrying whether her breasts are as big as her contemporaries .
# don ' t you have bigger fish to f ##ry ?
# although this is an important subject , there are bigger fish to f ##ry .
# am ##eric ##ans are going to have far bigger fish to f ##ry at home soon enough .
#
# Idiom usage word:  fish
# Paraphrase word:  problems
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.8083144174681769
# literal_to_literal : 0.8279292600022422
# fig_to_fig : 0.884190171957016
# fig_to_paraphrase : 0.6284329676628113
# literal_to_paraphrase : 0.6244223760233985
# fig_to_random : 0.6387207573110407
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 8.204765796661377
# literal_to_literal : 7.696328401565552
# fig_to_fig : 6.333995389938354
# fig_to_paraphrase : 11.664737033843995
# literal_to_paraphrase : 11.600088416205512
# fig_to_random : 11.397953362898393
#
#
#
#
#
# Example 7
# Figurative phrases:
# la ##fa ##ye ##tte , on the other hand , is one of the more culturally diverse cities i know .
# every minute of down ##time for a large site , on the other hand , could mean hundreds if not thousands of dollars in lost revenue .
# on the other hand , it is kind of distract ##ing .
# sa ##ms ##ung ' s hardware pioneering , on the other hand , needs more work .
# my husband , on the other hand , goes several times a week and doesn ' t like to miss it .
#
# Idiom usage word:  hand
# Paraphrase word:  perspective
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.4448190474510193
# literal_to_literal : 0.6856665929158529
# fig_to_fig : 0.8623103141784668
# fig_to_paraphrase : 0.48234714070955914
# literal_to_paraphrase : 0.5456911272472805
# fig_to_random : 0.4382158945907246
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 16.497327251434328
# literal_to_literal : 11.067494572533501
# fig_to_fig : 8.940852975845337
# fig_to_paraphrase : 15.927905993991429
# literal_to_paraphrase : 13.368042871687148
# fig_to_random : 16.336826393821024
#
#
#
#
#
# Example 8
# Figurative phrases:
# isn ' t the elephant in the room how the f he ' s typing without arms ?
# in the interview , c ##rump described race as being the elephant in the room when it comes to the tray ##von case .
# there is a bit of an elephant in the room at the moment about the lack of openly the ##ist posters .
# let me first address the elephant in the room .
# this is the elephant in the room we ' ve all been waiting for , " b ##ur ##ris said .
#
# Idiom usage word:  elephant
# Paraphrase word:  un
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.7654481649398803
# literal_to_literal : 0.849217661552959
# fig_to_fig : 0.8382633268833161
# fig_to_paraphrase : 0.5010183960199356
# literal_to_paraphrase : 0.5152376784218682
# fig_to_random : 0.5678158181905747
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 9.058786053127713
# literal_to_literal : 7.15807659096188
# fig_to_fig : 7.572375106811523
# fig_to_paraphrase : 14.36325828552246
# literal_to_paraphrase : 14.049650308820937
# fig_to_random : 12.841728839874268
#
#
#
#
#
# Example 9
# Figurative phrases:
# i feel like we ' re on the same page ; th ##o you ' re much further along in bad ##ass status .
# although ant ##hon ##y is doing all he can to improve his game , he must also make sure he is on the same page with his teammates .
# we can all try to get on the same page as far as what ps ##al ##ms , readings and collects to use .
# or you could let him know that you see marriage in your future and only want to date men who are on the same page .
# i think you and i are on the same page .
#
# Idiom usage word:  page
# Paraphrase word:  understanding
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.6991196937031217
# literal_to_literal : 0.7255105806721581
# fig_to_fig : 0.8266908049583435
# fig_to_paraphrase : 0.6161864006519318
# literal_to_paraphrase : 0.5579227424330182
# fig_to_random : 0.5992906844615936
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 10.868789121839736
# literal_to_literal : 10.468952523337471
# fig_to_fig : 8.091364479064941
# fig_to_paraphrase : 12.05518669128418
# literal_to_paraphrase : 13.092053582933215
# fig_to_random : 12.572760105133057
#
#
#
#
#
# Example 10
# Figurative phrases:
# and if you ' ve resort ##ed to name - calling , maybe you should just call it a day , as you have obviously run out of actual * arguments * .
# buy ' em off , and call it a day .
# rather than just return it and call it a day , i restored the device from scratch .
# i usually just call it a day , scout out the water or go for a hike .
# after a couple of hours of enjoying the surfing , without another soul in sight since this spot hardly ever has good waves , i was about to call it a day and go back home .
#
# Idiom usage word:  day
# Paraphrase word:  finish
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.6623427152633667
# literal_to_literal : 0.6792908079094357
# fig_to_fig : 0.8674263536930085
# fig_to_paraphrase : 0.5744725972414017
# literal_to_paraphrase : 0.5778993467489878
# fig_to_random : 0.5644134024779002
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 11.426070721944173
# literal_to_literal : 11.138932625452677
# fig_to_fig : 7.11158447265625
# fig_to_paraphrase : 12.729449272155762
# literal_to_paraphrase : 12.723452059427897
# fig_to_random : 12.805624643961588
#
#
#
#
#
# Example 11
# Figurative phrases:
# why did you have to let the cat out of the bag like that ?
# i don ' t want to let the cat out of the bag yet , " he said .
# i ' m worried of not only causing discomfort for my dad , but also humiliation for my mom if an ##nie decides to let the cat out of the bag .
# she didn ' t mean to let the cat out of the bag .
# the point was that once i let the cat out of the bag , the secret cease ##s to be a secret anymore and defeats more than one purpose .
#
# Idiom usage word:  cat
# Paraphrase word:  secret
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.8782401402791341
# literal_to_literal : 0.8856872916221619
# fig_to_fig : 0.9573121070861816
# fig_to_paraphrase : 0.6532250452041626
# literal_to_paraphrase : 0.6483950840102302
# fig_to_random : 0.6578912901878357
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 6.361712265014648
# literal_to_literal : 6.183140979872809
# fig_to_fig : 3.756807780265808
# fig_to_paraphrase : 11.163477821350098
# literal_to_paraphrase : 11.258840751647949
# fig_to_random : 11.275693187713623

# %% [markdown]
# # Fine-tuned on our idiom data

# %%
# Fine-tuned on all our idiom data

word_args = {
   'comparison_type': 'words',
    'input': 'word_vec_sim_test.txt',
    'embedding_model': 'models/idiom_all',
    'run_name': 'idiom_all_1',
    'embedding_batch_size': 32,
#     'embedding_cache': None,
    'embedding_cache': 'cache/idiom_all_1',
    'show_pca': True
}

run_vector_similarity.main(objectview(word_args))
# Out:
# Example 0
# Figurative phrases:
# soon we ' re going to hit the sack .
# so if you ' re ex ##er ##cis ##ing close to bed ##time , calm down by me ##dit ##ating or doing a few gentle yoga poses before you hit the sack .
# would it be okay with you if we had a bite to eat now and hit the sack early ?
# i think i ' m gonna hit the sack before i get even more uncomfortable .
# but before you hit the sack , follow this expert advice for solving morning beauty emerge ##ncies .
#
# Idiom usage word:  sack
# Paraphrase word:  bed
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.6767412424087524
# literal_to_literal : 0.8267937848965327
# fig_to_fig : 0.8518805384635926
# fig_to_paraphrase : 0.5852113509178162
# literal_to_paraphrase : 0.6296505298879411
# fig_to_random : 0.5663954794406891
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 10.900913535224067
# literal_to_literal : 7.798722426096599
# fig_to_fig : 7.4851149559021
# fig_to_paraphrase : 12.586040019989014
# literal_to_paraphrase : 11.665716330210367
# fig_to_random : 12.804740619659423
#
#
#
#
#
# Example 1
# Figurative phrases:
# it ' s not always easy making decisions on the fly as a d ##m but here ' s what he probably should have done so that it wasn ' t obvious .
# that ' s a fairly advanced feature for any presentation device and requires a lot of computing power to do on the fly .
# but i certainly won ' t let them know i ' m t ##we ##aking things on the fly .
# operating on the fly , o ##ba ##ma made a tough call and it seems like it was a good one .
# often these changes happened on the fly , daily , in response to sudden customer demand or customer loss .
#
# Idiom usage word:  fly
# Paraphrase word:  spontaneous
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.6286565437912941
# literal_to_literal : 0.7864754987614495
# fig_to_fig : 0.8484551548957825
# fig_to_paraphrase : 0.5628174196590077
# literal_to_paraphrase : 0.6270705922083422
# fig_to_random : 0.5311387938261032
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 12.420344400405884
# literal_to_literal : 8.662573439734322
# fig_to_fig : 8.350192546844482
# fig_to_paraphrase : 13.468639893965287
# literal_to_paraphrase : 11.587677370418202
# fig_to_random : 14.049669532775878
#
#
#
#
#
# Example 2
# Figurative phrases:
# razor is aiming for that same market corner and they have set the bar rather high for it based on speculation .
# but apple has set the bar for magical technology and the i ##phone 5 failed to impress .
# take care not to set the bar too low - - - - low goals will not m ##ot ##ivate you .
# it ' s worth noting for ram ##s fans , though , that they set the bar insane ##ly high by hitting on so many rookie ##s .
# after it was released in 1998 , grim fan ##dan ##go blew everyone away and set the bar ridiculous ##ly high for adventure games .
#
# Idiom usage word:  bar
# Paraphrase word:  standard
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.6691197050942315
# literal_to_literal : 0.8189938416083654
# fig_to_fig : 0.8539827942848206
# fig_to_paraphrase : 0.6084752708673478
# literal_to_paraphrase : 0.5956964247756534
# fig_to_random : 0.5264800071716309
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 11.159457291497125
# literal_to_literal : 7.89747401078542
# fig_to_fig : 7.699671840667724
# fig_to_paraphrase : 12.21639642715454
# literal_to_paraphrase : 11.941555086771647
# fig_to_random : 13.562500705718994
#
#
#
#
#
# Example 3
# Figurative phrases:
# i du ##nn ##o , what ' s the opportunity cost in the long run ?
# that marriage must be good for children is an argument that , by itself , can not pre ##va ##il in the attempt to preserve marriage in the long run .
# i would suggest buying your milk at grocery stores , in the long run you ' ll save money versus making multiple trips .
# in the long run , people buy from artists they trust .
# some organizations th ##rive for only a few quarters , but in the long run , they may be extremely unstable .
#
# Idiom usage word:  run
# Paraphrase word:  future
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.46033926010131837
# literal_to_literal : 0.7522299670510821
# fig_to_fig : 0.8662541747093201
# fig_to_paraphrase : 0.5382847636938095
# literal_to_paraphrase : 0.5405432413021724
# fig_to_random : 0.4071491632196638
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 16.302055740356444
# literal_to_literal : 9.284706672032675
# fig_to_fig : 8.954452848434448
# fig_to_paraphrase : 15.459321613311767
# literal_to_paraphrase : 13.353841951158312
# fig_to_random : 16.870361836751304
#
#
#
#
#
# Example 4
# Figurative phrases:
# you ' re just going to have to bite the bullet and get through it .
# one possible response to this second example is to bite the bullet and to argue that from the point of view of fundamental physics , there really is no difference .
# like everything else in life , you ' re kind of just forced to bite the bullet and see the bigger picture .
# at that point you should bite the bullet and spend $ 2 , 199 on a 15 - inch re ##tina mac ##book pro that offers the same storage space .
# that ' s why it ' s time to bite the bullet , suck it up and look to the future .
#
# Idiom usage word:  bullet
# Paraphrase word:  situation
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.7305777549743653
# literal_to_literal : 0.7952284399006102
# fig_to_fig : 0.8938157558441162
# fig_to_paraphrase : 0.6524246764183045
# literal_to_paraphrase : 0.6161638011535009
# fig_to_random : 0.6437401576475663
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 9.60213762919108
# literal_to_literal : 8.402503344747755
# fig_to_fig : 5.878700685501099
# fig_to_paraphrase : 10.777306709289551
# literal_to_paraphrase : 11.534007687038846
# fig_to_random : 10.892131302573464
#
#
#
#
#
# Example 5
# Figurative phrases:
# i think i ' m going to hold on to it and maybe i ' ll find something to do with it later down the road .
# the goal may be a long way down the road , but the humanity ' s total command over nature should be ultimate aim .
# we support terrorist elements , most recently in s ##yr ##ia and l ##ib ##ya , but before that in i ##ra ##q , b ##os ##nia , k ##oso ##vo , and a ##f ##ghan ##istan , and then find ourselves fighting them down the road .
# who ' s going to pay for all of that free stuff down the road ?
# this problem has been kicked down the road long enough .
#
# Idiom usage word:  road
# Paraphrase word:  future
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.7754542761378818
# literal_to_literal : 0.8146400335762236
# fig_to_fig : 0.8368042409420013
# fig_to_paraphrase : 0.6005883914232254
# literal_to_paraphrase : 0.5645231475432714
# fig_to_random : 0.6454861376020643
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 8.761450174119737
# literal_to_literal : 7.862831380632189
# fig_to_fig : 7.557174491882324
# fig_to_paraphrase : 12.468778133392334
# literal_to_paraphrase : 12.861229059431288
# fig_to_random : 11.003339301215277
#
#
#
#
#
# Example 6
# Figurative phrases:
# i think he has bigger fish to f ##ry .
# jazz has bigger fish to f ##ry than worrying whether her breasts are as big as her contemporaries .
# don ' t you have bigger fish to f ##ry ?
# although this is an important subject , there are bigger fish to f ##ry .
# am ##eric ##ans are going to have far bigger fish to f ##ry at home soon enough .
#
# Idiom usage word:  fish
# Paraphrase word:  problems
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.8407275040944417
# literal_to_literal : 0.8520516984992557
# fig_to_fig : 0.9180068492889404
# fig_to_paraphrase : 0.658285197019577
# literal_to_paraphrase : 0.6431960609224108
# fig_to_random : 0.66999305378307
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 7.563794835408529
# literal_to_literal : 7.219765318764581
# fig_to_fig : 5.414122271537781
# fig_to_paraphrase : 11.236526737213135
# literal_to_paraphrase : 11.37243612077501
# fig_to_random : 10.758187935569069
#
#
#
#
#
# Example 7
# Figurative phrases:
# la ##fa ##ye ##tte , on the other hand , is one of the more culturally diverse cities i know .
# every minute of down ##time for a large site , on the other hand , could mean hundreds if not thousands of dollars in lost revenue .
# on the other hand , it is kind of distract ##ing .
# sa ##ms ##ung ' s hardware pioneering , on the other hand , needs more work .
# my husband , on the other hand , goes several times a week and doesn ' t like to miss it .
#
# Idiom usage word:  hand
# Paraphrase word:  perspective
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.5113712608814239
# literal_to_literal : 0.6995055437088012
# fig_to_fig : 0.8889623880386353
# fig_to_paraphrase : 0.5568342155880398
# literal_to_paraphrase : 0.5642332514127095
# fig_to_random : 0.5002259108153256
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 15.227084407806396
# literal_to_literal : 10.65012436972724
# fig_to_fig : 7.837074327468872
# fig_to_paraphrase : 14.602415317959256
# literal_to_paraphrase : 13.012104394700792
# fig_to_random : 15.102009825272994
#
#
#
#
#
# Example 8
# Figurative phrases:
# isn ' t the elephant in the room how the f he ' s typing without arms ?
# in the interview , c ##rump described race as being the elephant in the room when it comes to the tray ##von case .
# there is a bit of an elephant in the room at the moment about the lack of openly the ##ist posters .
# let me first address the elephant in the room .
# this is the elephant in the room we ' ve all been waiting for , " b ##ur ##ris said .
#
# Idiom usage word:  elephant
# Paraphrase word:  un
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.7865327093336317
# literal_to_literal : 0.8793286134799322
# fig_to_fig : 0.8514245331287384
# fig_to_paraphrase : 0.48799042344093324
# literal_to_paraphrase : 0.516651713848114
# fig_to_random : 0.6544440229733784
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 8.261254776848688
# literal_to_literal : 6.187162929111057
# fig_to_fig : 6.86992039680481
# fig_to_paraphrase : 14.543791751861573
# literal_to_paraphrase : 14.136156166924371
# fig_to_random : 10.58853850894504
#
#
#
#
#
# Example 9
# Figurative phrases:
# i feel like we ' re on the same page ; th ##o you ' re much further along in bad ##ass status .
# although ant ##hon ##y is doing all he can to improve his game , he must also make sure he is on the same page with his teammates .
# we can all try to get on the same page as far as what ps ##al ##ms , readings and collects to use .
# or you could let him know that you see marriage in your future and only want to date men who are on the same page .
# i think you and i are on the same page .
#
# Idiom usage word:  page
# Paraphrase word:  understanding
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.6805305043856303
# literal_to_literal : 0.7120502417286237
# fig_to_fig : 0.8244578003883362
# fig_to_paraphrase : 0.6243675541877747
# literal_to_paraphrase : 0.5634634133842257
# fig_to_random : 0.6034352773427963
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 11.176329231262207
# literal_to_literal : 10.548553347587585
# fig_to_fig : 8.266074609756469
# fig_to_paraphrase : 12.101257553100586
# literal_to_paraphrase : 13.039467779795329
# fig_to_random : 12.338570938110351
#
#
#
#
#
# Example 10
# Figurative phrases:
# and if you ' ve resort ##ed to name - calling , maybe you should just call it a day , as you have obviously run out of actual * arguments * .
# buy ' em off , and call it a day .
# rather than just return it and call it a day , i restored the device from scratch .
# i usually just call it a day , scout out the water or go for a hike .
# after a couple of hours of enjoying the surfing , without another soul in sight since this spot hardly ever has good waves , i was about to call it a day and go back home .
#
# Idiom usage word:  day
# Paraphrase word:  finish
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.6694375620947943
# literal_to_literal : 0.6923163963688744
# fig_to_fig : 0.8590556979179382
# fig_to_paraphrase : 0.5578534471988678
# literal_to_paraphrase : 0.5692470656500922
# fig_to_random : 0.6064455227418379
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 11.160408528645833
# literal_to_literal : 10.711647590001425
# fig_to_fig : 7.289607906341553
# fig_to_paraphrase : 12.970637855529786
# literal_to_paraphrase : 12.753994899325901
# fig_to_random : 11.881949199329723
#
#
#
#
#
# Example 11
# Figurative phrases:
# why did you have to let the cat out of the bag like that ?
# i don ' t want to let the cat out of the bag yet , " he said .
# i ' m worried of not only causing discomfort for my dad , but also humiliation for my mom if an ##nie decides to let the cat out of the bag .
# she didn ' t mean to let the cat out of the bag .
# the point was that once i let the cat out of the bag , the secret cease ##s to be a secret anymore and defeats more than one purpose .
#
# Idiom usage word:  cat
# Paraphrase word:  secret
# Cosine similarity scores (higher is 'closer')
# fig_to_literal : 0.9020244359970093
# literal_to_literal : 0.9079916708999209
# fig_to_fig : 0.9676134645938873
# fig_to_paraphrase : 0.6820755016803741
# literal_to_paraphrase : 0.6884418288866679
# fig_to_random : 0.7030361268255446
#
#
# Euclidean distance scores (higher is 'further')
# fig_to_literal : 5.546448718176948
# literal_to_literal : 5.328405539194743
# fig_to_fig : 3.2026201486587524
# fig_to_paraphrase : 10.47796579360962
# literal_to_paraphrase : 10.310813321007622
# fig_to_random : 9.82000675201416

# %%
# BERT - LARGE

sent_args = {
   'comparison_type': 'para_pairs',
    'input': '../probe/output/daniel/train_classifications.tsv',
    'embedding_model': 'bert-large-uncased',
    'run_name': 'paraphrase_large_test',
    'embedding_batch_size': 16,
    'embedding_cache': 'paraphrase_large_test'
}

# main(objectview(sent_args))

# %%
sent_args = {
   'comparison_type': 'para_pairs',
    'input': '../probe/output/daniel/train_classifications.tsv',
    'embedding_model': 'bert-large-uncased',
    'run_name': 'paraphrase_large_test',
    'embedding_batch_size': 16,
    'embedding_cache': 'cache/paraphrase_large_test'
}

# main(objectview(sent_args))
